# %% [markdown]
# ## Importing libraries

# %%
from sklearn.datasets import load_diabetes #library for dataset
import pandas as pd
import numpy as np
import matplotlib as mp #for ploting graphs
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression #for Machine learning models

# %% [markdown]
# ## Loading Dataset

# %%
# Load the diabetes dataset
diabetes = load_diabetes()

# We'll use only one feature for simplicity
X = diabetes.data[:, np.newaxis, 2]
y = diabetes.target

# Create a DataFrame
data = pd.DataFrame(np.hstack((X, y[:, np.newaxis])), columns=['Feature', 'Target'])
print(data.head())
# Out:
#     Feature  Target
# 0  0.061696   151.0
# 1 -0.051474    75.0
# 2  0.044451   141.0
# 3 -0.011595   206.0
# 4 -0.036385   135.0

# %% [markdown]
# ## Ploting data

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data['Feature'], data['Target'], color='blue', alpha=0.5, label='Data points')
plt.plot(data['Feature'], y_pred, color='red', linewidth=2, label='Regression line')

# Add title and labels
plt.title('Linear Regression on Diabetes Dataset')
plt.xlabel('Feature')
plt.ylabel('Target')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ## Applying linear Regression Model

# %%
# Fit the linear regression model
model = LinearRegression()
model.fit(X, y)

# Make predictions using the model
y_pred = model.predict(X)

# %% [markdown]
# ## Graph After applying Linear Regression

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data['Feature'], data['Target'], color='blue', alpha=0.5, label='Data points')
plt.plot(data['Feature'], y_pred, color='red', linewidth=2, label='Regression line')

# Add title and labels
plt.title('Linear Regression on Diabetes Dataset')
plt.xlabel('Feature')
plt.ylabel('Target')
plt.legend()

# Show the plot
plt.show()
